# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# # 1. Modeling the activity of a single neuron

# %%
data = np.loadtxt("Data_neuron.txt")

# %% [markdown]
# ### Q1

# %%
# Calculate time intervals between successive spikes
time_intervals = np.diff(data)

# Calculate refractory period
refractory_period = np.min(time_intervals)

# Plot the distribution of time intervals
plt.hist(time_intervals, bins=50, density=True)
plt.xlabel('Time Interval (ms)')
plt.ylabel('Probability Density')
plt.title('Distribution of Time Intervals Between Successive Spikes')
plt.grid(True)
plt.show()

plt.savefig("figures/Q1")

print('Refractory period is', refractory_period, 'ms')
# Out:
# Refractory period is 1.8999999999650754 ms

# %% [markdown]
# ### Q2

# %%
def exponential_decay(t, A, rate):
    return A * rate * np.exp(-rate*t)

plt.hist(time_intervals, bins=50, density=True, label='Data')

hist, bin_edges = np.histogram(time_intervals, bins=50, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Fit an exponential function to the distribution
popt, pcov = curve_fit(exponential_decay, bin_centers, hist)
decay_rate = popt[1]

# Plot the fitted exponential function
plt.plot(bin_centers, exponential_decay(bin_centers, *popt), 'r--', label='Exponential Fit')

plt.xlabel('Time Interval (ms)')
plt.ylabel('Probability Density')
plt.title('Distribution of Time Intervals Between Successive Spikes')
plt.grid(True)
plt.legend()
plt.show()

plt.savefig("figures/Q2")

print(popt[0])
print("Decay rate is", decay_rate)
# Out:
# 1.2090124398506266
# Decay rate is 0.09994167661529435

# %% [markdown]
# # 3. Application to the analysis of the US supreme Court

# %% [markdown]
# ### Q6.1

# %%
file = open('US_SupremeCourt_n9_N895.txt', 'r')
data = file.readlines()

print(data)

print("Total number of datapoints is", len(data))

print("Number of unique states observed is", len(np.unique(data)))
# Out:
# ['101111111\n', '111111111\n', '111111111\n', '000000000\n', '101100100\n', '000100100\n', '111111111\n', '000000000\n', '111111111\n', '111111111\n', '101000101\n', '101111111\n', '101110111\n', '111111111\n', '000100100\n', '100110100\n', '000000000\n', '101111111\n', '001000000\n', '111111111\n', '100100100\n', '100100100\n', '101111111\n', '111111111\n', '111011000\n', '101111101\n', '111111111\n', '000000100\n', '111111111\n', '110010011\n', '111111111\n', '111111111\n', '111111111\n', '111111111\n', '001000001\n', '101111111\n', '111111111\n', '111111111\n', '000000000\n', '101111101\n', '100100000\n', '110110110\n', '100110100\n', '000000000\n', '101110111\n', '011101011\n', '101110100\n', '111111111\n', '111111111\n', '101001000\n', '000110100\n', '000000000\n', '101111110\n', '101100100\n', '000000000\n', '000000000\n', '111111111\n', '100000100\n', '101111111\n', '101110100\n', '000000000\n', '101110100\n', '101111111\n', '111111111\n', '000000000\n', '001001100\n', '000000000\n', '101111111\n', '100101100\n', '100110110\n', '101110100\n', '000000000\n', '000000000\n', '111111111\n', '000110100\n', '101100101\n', '100110111\n', '100100100\n', '111111111\n', '101111101\n', '101110100\n', '101110100\n', '101110100\n', '000000000\n', '111111111\n', '101111111\n', '111011110\n', '000000000\n', '100000100\n', '111111111\n', '000000000\n', '111111111\n', '000100100\n', '100100100\n', '000000000\n', '111111111\n', '010000100\n', '000000000\n', '111111111\n', '101111111\n', '010000001\n', '111111111\n', '101111111\n', '101110101\n', '111111111\n', '111111111\n', '101100110\n', '111111111\n', '111111111\n', '001100100\n', '111111111\n', '000000000\n', '101110100\n', '100110100\n', '000000000\n', '000000000\n', '100110100\n', '101111111\n', '101110101\n', '000000000\n', '111111111\n', '101100100\n', '101101111\n', '101111111\n', '000000000\n', '000000000\n', '000000000\n', '011011001\n', '100100100\n', '101000100\n', '000000100\n', '000100000\n', '000000000\n', '111111111\n', '111111111\n', '000000000\n', '000000000\n', '111111111\n', '000000000\n', '111111111\n', '111111111\n', '101110100\n', '101110100\n', '100100000\n', '100110110\n', '010001011\n', '110111110\n', '000000000\n', '101110100\n', '101111110\n', '000000000\n', '101111111\n', '101111111\n', '101111101\n', '101111111\n', '100100100\n', '101100100\n', '101111101\n', '111111111\n', '000100100\n', '000100100\n', '111101101\n', '100000010\n', '101111101\n', '111111111\n', '111111111\n', '000000000\n', '111111111\n', '101111111\n', '000000000\n', '101111111\n', '000000000\n', '001100100\n', '100100100\n', '111111111\n', '101100100\n', '000000000\n', '000000000\n', '111111111\n', '101111111\n', '000000000\n', '010000000\n', '000000000\n', '000000000\n', '000000000\n', '111111111\n', '000110100\n', '101101111\n', '111111111\n', '000000000\n', '111111111\n', '111111111\n', '101111111\n', '101111110\n', '000000000\n', '111111111\n', '111111111\n', '111011110\n', '000000000\n', '000000000\n', '110011001\n', '111111111\n', '000000000\n', '111111111\n', '101111111\n', '100000000\n', '111111111\n', '101110101\n', '111111111\n', '101110100\n', '111111111\n', '111111111\n', '101110111\n', '000000000\n', '100111100\n', '101111100\n', '100100110\n', '111111111\n', '111111111\n', '111111111\n', '000000000\n', '000000000\n', '101111100\n', '101110100\n', '111111111\n', '101000011\n', '001100100\n', '011111110\n', '000000000\n', '111111111\n', '111111111\n', '111111111\n', '101111111\n', '100100100\n', '101110100\n', '001100100\n', '101110100\n', '111111111\n', '101110100\n', '101110100\n', '100110100\n', '101110100\n', '100110100\n', '101111101\n', '011010011\n', '001110100\n', '100100100\n', '111111111\n', '111111111\n', '101111110\n', '000000000\n', '101110100\n', '000000000\n', '101111110\n', '101111111\n', '000000000\n', '111111111\n', '111110110\n', '111111111\n', '000000000\n', '101111111\n', '000000000\n', '111111111\n', '000000000\n', '000000000\n', '010000010\n', '00000000 ...
# Total number of datapoints is 895
# Number of unique states observed is 128

# %% [markdown]
# ### Q6.2 (Bonus)

# %% [markdown]
# ### Q6.3

# %%
# Convert strings to arrays of integers
data_int = [[int(char) for char in line.strip()] for line in data]

# Exchange each 0 for -1 in the dataset
data_modified = [[-1 if value == 0 else value for value in line] for line in data_int]

# %%
def empirical_averages(judges):
    averages = []
    for judge in judges:
        i = judge - 1
        si_values = [data_point[i] for data_point in data_modified]
        avg_si = sum(si_values) / len(si_values)
        averages.append(avg_si)
    return averages

judges = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# Calculate and plot empirical averages for all judges
averages = empirical_averages(judges)

# Plot empirical averages
plt.plot(judges, averages, marker='o')
plt.xlabel(r'Judge Index $i$')
plt.ylabel(r'Empirical Average $\langle s_i\rangle_D$')
plt.xticks(judges)
plt.grid(True)
plt.show()
